# %%
from selenium import webdriver
import time

# webdriver_options = webdriver.ChromeOptions()
# webdriver_options .add_argument('headless')

driver = webdriver.Chrome('/Users/WMHY/Downloads/chromedriver')

# %%
url = 'https://www.daejeocamping.com/Main.mobiz?camptype=camp01#'
driver.get(url)
time.sleep(0.5)

xpath = "//a[@href='/Login.mobiz']"
driver.find_element_by_xpath(xpath).click()
time.sleep(0.5)

xpath = "//input[@id='userid']"
driver.find_element_by_xpath(xpath).send_keys("woomir")
time.sleep(0.1)

xpath = "//input[@id='passwd']"
driver.find_element_by_xpath(xpath).send_keys("$52Telecast")
time.sleep(0.1)

xpath = "//input[@value='로그인']"
driver.find_element_by_xpath(xpath).click()
time.sleep(0.5)

xpath = "//a[@href='/Camp.mobiz?camptype=camp01']"
driver.find_element_by_xpath(xpath).click()
time.sleep(0.5)

# driver.get("https://hwamyungcamping.com/reservation/real_time")
# time.sleep(0.3)

# driver.switch_to.alert.accept()
# time.sleep(0.3)

xpath = "//select[@id='term']"
driver.find_element_by_xpath(xpath).click()
time.sleep(0.2)

xpath = "//option[@value='2']"
driver.find_element_by_xpath(xpath).click()
time.sleep(0.2)

# driver.switch_to.alert.accept()
# time.sleep(0.3)

xpath = "//input[@id='resdate']"
driver.find_element_by_xpath(xpath).click()
time.sleep(0.3)

xpath = "//*[@id='ui-datepicker-div']/div/a[2]"
driver.find_element_by_xpath(xpath).click()
time.sleep(0.2)

# xpath = "/html/body/div[6]/table/tbody/tr[3]/td[5]/a"
# driver.find_element_by_xpath(xpath).click()
# time.sleep(0.1)

# driver.switch_to.alert.accept()
# time.sleep(0.3)

# url='https://hwamyungcamping.com/reservation/real_time?user_id=woomir&site_id=&site_type=&dis_rate=0&user_dis_rate=&resdate=2021-04-16&schGugun=2&price=0&bagprice=2000&allprice=0'
# driver.get(url)
# time.sleep(0.5)

# 4월 12일
xpath = "//*[@id='ui-datepicker-div']/table/tbody/tr[3]/td[2]/a"
driver.find_element_by_xpath(xpath).click()
time.sleep(0.5)

xpath = "//label[@for='camp40']"
driver.find_element_by_xpath(xpath).click()
time.sleep(0.1)

xpath = "//input[@value='다음']"
driver.find_element_by_xpath(xpath).click()
time.sleep(0.5)

xpath = "//input[@name='tel']"
driver.find_element_by_xpath(xpath).send_keys("68어4343")
time.sleep(0.1)

xpath = "//input[@name='carnumber']"
driver.find_element_by_xpath(xpath).send_keys("4")
time.sleep(0.1)

xpath = "//input[@name='carmodel']"
driver.find_element_by_xpath(xpath).send_keys("1")
time.sleep(0.1)

# xpath = "//input[@value='예약완료']"
# driver.find_element_by_xpath(xpath).click()
# Out:
# ---------------------------------------------------------------------------
# ElementNotInteractableException           Traceback (most recent call last)
# <ipython-input-5-6abbf8ecf031> in <module>
#       4
#       5 xpath = "//a[@href='/Login.mobiz']"
# ----> 6 driver.find_element_by_xpath(xpath).click()
#       7 time.sleep(0.5)
#       8
#
# /usr/local/lib/python3.9/site-packages/selenium/webdriver/remote/webelement.py in click(self)
#      78     def click(self):
#      79         """Clicks the element."""
# ---> 80         self._execute(Command.CLICK_ELEMENT)
#      81
#      82     def submit(self):
#
# /usr/local/lib/python3.9/site-packages/selenium/webdriver/remote/webelement.py in _execute(self, command, params)
#     631             params = {}
#     632         params['id'] = self._id
# --> 633         return self._parent.execute(command, params)
#     634
#     635     def find_element(self, by=By.ID, value=None):
#
# ...
